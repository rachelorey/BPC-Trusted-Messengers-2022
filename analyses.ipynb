# %%
import pandas as pd
import mc_processor

# %%
# read results files
codebook = pd.read_csv('raw/levels_codebook.csv', encoding='utf-8')
data = pd.read_csv('raw/data.csv', encoding='utf-8')
q_codebook = pd.read_csv('raw/question_codebook.csv', encoding='utf-8', index_col = 'qid')

# q_codebook into dict
q_codebook = q_codebook.to_dict().get('qidFull')

# %%
nulldata = pd.DataFrame(data.isnull().sum(),columns=["Sum_Null"]) ##2203 rows in entire dataset
nulldata.sort_values(by=["Sum_Null"],ascending=False,inplace=True)

# nulldata[nulldata["Sum_Null"]>0].head(20)

# %% [markdown]
# Use `get_percents` to get percent who selected each option, works for questions that have multiple or single selection.
#
# Demo input optional. For all demo categories, see next cell.

# %%
# all demo categories
for key in q_codebook:
    if "dem" in key:
        print(key)
# Out:
# xdemAll
# BPCdem1
# BPCdem2
# BPCxdem1
# BPCxdem2
# BPCxdem3
# BPCxdem4
# BPCxdem5
# BPCxdem6
# BPCxdem7
# BPCxdem8
# BPCxdem9
# demAgeGeneration
# demBlackBin
# demRaceOther
# xBPC7dem
# xdemBidenApprove
# xdemBidenApprove2
# xdemBidenFav
# xdemBidenFavFull
# xdemEmploy
# xdemEvang
# xdemGender
# xdemHispBin
# xdemIdeo3
# xdemInc3
# xdemMilHH1
# xdemReligion
# xdemReligOther
# xdemUsr
# xdemWhite

# %%
# testing on range of questions

mc_processor.get_percents(data,codebook,q_codebook,question="BPC1").style.format("{:.0%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_03e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03e26_level0_col0" class="col_heading level0 col0" >overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03e26_level0_row0" class="row_heading level0 row0" >Your local election office</th>
#       <td id="T_03e26_row0_col0" class="data row0 col0" >40%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row1" class="row_heading level0 row1" >Search through Google or other search engines</th>
#       <td id="T_03e26_row1_col0" class="data row1 col0" >39%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row2" class="row_heading level0 row2" >Your state election office</th>
#       <td id="T_03e26_row2_col0" class="data row2 col0" >33%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row3" class="row_heading level0 row3" >Friends and family</th>
#       <td id="T_03e26_row3_col0" class="data row3 col0" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row4" class="row_heading level0 row4" >Local or regional television</th>
#       <td id="T_03e26_row4_col0" class="data row4 col0" >18%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row5" class="row_heading level0 row5" >Social media such as Facebook, Twitter, or Instagram</th>
#       <td id="T_03e26_row5_col0" class="data row5 col0" >17%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row6" class="row_heading level0 row6" >National television</th>
#       <td id="T_03e26_row6_col0" class="data row6 col0" >15%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row7" class="row_heading level0 row7" >Television news website</th>
#       <td id="T_03e26_row7_col0" class="data row7 col0" >13%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row8" class="row_heading level0 row8" >Print publications, such as newspapers or magazines</th>
#       <td id="T_03e26_row8_col0" class="data row8 col0" >9%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row9" class="row_heading level0 row9" >Print publications news websites</th>
#       <td id="T_03e26_row9_col0" class="data row9 col0" >9%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row10" class="row_heading level0 row10" >Radio</th>
#       <td id="T_03e26_row10_col0" class="data row10 col0" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row11" class="row_heading level0 row11" >I do not consume information about how to vote</th>
#       <td id="T_03e26_row11_col0" class="data row11 col0" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row12" class="row_heading level0 row12" >Podcasts</th>
#       <td id="T_03e26_row12_col0" class="data row12 col0" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row13" class="row_heading level0 row13" >Blogs or online forums</th>
#       <td id="T_03e26_row13_col0" class="data row13 col0" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row14" class="row_heading level0 row14" >Don't know/ no opinion</th>
#       <td id="T_03e26_row14_col0" class="data row14 col0" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_03e26_level0_row15" class="row_heading level0 row15" >Other, please specify</th>
#       <td id="T_03e26_row15_col0" class="data row15 col0" >1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# testing on range of questions

questions = []
for i in range(1,5):
    questions.append("BPC"+str(i))

for question in questions:
    
    #print question text
    for key in q_codebook:
        # print(question)
        if key.startswith(question):
            print("\n",question, q_codebook[key].split("---")[0])
            break
    try:  
        display(mc_processor.get_percents(data,codebook,q_codebook,question,demo="xpid3").style.format("{:.0%}"))
    except:
        print(f"Issue with {question}\n")
# Out:
#  BPC1 In the United States, there is information voters need to register and vote. Where are you most likely to look for this information? You may select up to 3 choices. \\ National television
# <style type="text/css">
# </style>
# <table id="T_9e817">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e817_level0_col0" class="col_heading level0 col0" >PID: Dem (no lean)</th>
#       <th id="T_9e817_level0_col1" class="col_heading level0 col1" >PID: Ind (no lean)</th>
#       <th id="T_9e817_level0_col2" class="col_heading level0 col2" >PID: Rep (no lean)</th>
#       <th id="T_9e817_level0_col3" class="col_heading level0 col3" >overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e817_level0_row0" class="row_heading level0 row0" >Your local election office</th>
#       <td id="T_9e817_row0_col0" class="data row0 col0" >38%</td>
#       <td id="T_9e817_row0_col1" class="data row0 col1" >39%</td>
#       <td id="T_9e817_row0_col2" class="data row0 col2" >42%</td>
#       <td id="T_9e817_row0_col3" class="data row0 col3" >40%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row1" class="row_heading level0 row1" >Search through Google or other search engines</th>
#       <td id="T_9e817_row1_col0" class="data row1 col0" >41%</td>
#       <td id="T_9e817_row1_col1" class="data row1 col1" >41%</td>
#       <td id="T_9e817_row1_col2" class="data row1 col2" >36%</td>
#       <td id="T_9e817_row1_col3" class="data row1 col3" >39%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row2" class="row_heading level0 row2" >Your state election office</th>
#       <td id="T_9e817_row2_col0" class="data row2 col0" >33%</td>
#       <td id="T_9e817_row2_col1" class="data row2 col1" >33%</td>
#       <td id="T_9e817_row2_col2" class="data row2 col2" >33%</td>
#       <td id="T_9e817_row2_col3" class="data row2 col3" >33%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row3" class="row_heading level0 row3" >Friends and family</th>
#       <td id="T_9e817_row3_col0" class="data row3 col0" >24%</td>
#       <td id="T_9e817_row3_col1" class="data row3 col1" >23%</td>
#       <td id="T_9e817_row3_col2" class="data row3 col2" >28%</td>
#       <td id="T_9e817_row3_col3" class="data row3 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row4" class="row_heading level0 row4" >Local or regional television</th>
#       <td id="T_9e817_row4_col0" class="data row4 col0" >21%</td>
#       <td id="T_9e817_row4_col1" class="data row4 col1" >15%</td>
#       <td id="T_9e817_row4_col2" class="data row4 col2" >17%</td>
#       <td id="T_9e817_row4_col3" class="data row4 col3" >18%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row5" class="row_heading level0 row5" >Social media such as Facebook, Twitter, or Instagram</th>
#       <td id="T_9e817_row5_col0" class="data row5 col0" >20%</td>
#       <td id="T_9e817_row5_col1" class="data row5 col1" >13%</td>
#       <td id="T_9e817_row5_col2" class="data row5 col2" >16%</td>
#       <td id="T_9e817_row5_col3" class="data row5 col3" >17%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row6" class="row_heading level0 row6" >National television</th>
#       <td id="T_9e817_row6_col0" class="data row6 col0" >18%</td>
#       <td id="T_9e817_row6_col1" class="data row6 col1" >11%</td>
#       <td id="T_9e817_row6_col2" class="data row6 col2" >16%</td>
#       <td id="T_9e817_row6_col3" class="data row6 col3" >15%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row7" class="row_heading level0 row7" >Television news website</th>
#       <td id="T_9e817_row7_col0" class="data row7 col0" >16%</td>
#       <td id="T_9e817_row7_col1" class="data row7 col1" >9%</td>
#       <td id="T_9e817_row7_col2" class="data row7 col2" >12%</td>
#       <td id="T_9e817_row7_col3" class="data row7 col3" >13%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row8" class="row_heading level0 row8" >Print publications, such as newspapers or magazines</th>
#       <td id="T_9e817_row8_col0" class="data row8 col0" >10%</td>
#       <td id="T_9e817_row8_col1" class="data row8 col1" >7%</td>
#       <td id="T_9e817_row8_col2" class="data row8 col2" >9%</td>
#       <td id="T_9e817_row8_col3" class="data row8 col3" >9%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row9" class="row_heading level0 row9" >Print publications news websites</th>
#       <td id="T_9e817_row9_col0" class="data row9 col0" >10%</td>
#       <td id="T_9e817_row9_col1" class="data row9 col1" >9%</td>
#       <td id="T_9e817_row9_col2" class="data row9 col2" >7%</td>
#       <td id="T_9e817_row9_col3" class="data row9 col3" >9%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row10" class="row_heading level0 row10" >Radio</th>
#       <td id="T_9e817_row10_col0" class="data row10 col0" >6%</td>
#       <td id="T_9e817_row10_col1" class="data row10 col1" >6%</td>
#       <td id="T_9e817_row10_col2" class="data row10 col2" >7%</td>
#       <td id="T_9e817_row10_col3" class="data row10 col3" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row11" class="row_heading level0 row11" >I do not consume information about how to vote</th>
#       <td id="T_9e817_row11_col0" class="data row11 col0" >4%</td>
#       <td id="T_9e817_row11_col1" class="data row11 col1" >8%</td>
#       <td id="T_9e817_row11_col2" class="data row11 col2" >6%</td>
#       <td id="T_9e817_row11_col3" class="data row11 col3" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row12" class="row_heading level0 row12" >Podcasts</th>
#       <td id="T_9e817_row12_col0" class="data row12 col0" >5%</td>
#       <td id="T_9e817_row12_col1" class="data row12 col1" >4%</td>
#       <td id="T_9e817_row12_col2" class="data row12 col2" >4%</td>
#       <td id="T_9e817_row12_col3" class="data row12 col3" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row13" class="row_heading level0 row13" >Blogs or online forums</th>
#       <td id="T_9e817_row13_col0" class="data row13 col0" >5%</td>
#       <td id="T_9e817_row13_col1" class="data row13 col1" >4%</td>
#       <td id="T_9e817_row13_col2" class="data row13 col2" >3%</td>
#       <td id="T_9e817_row13_col3" class="data row13 col3" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row14" class="row_heading level0 row14" >Don't know/ no opinion</th>
#       <td id="T_9e817_row14_col0" class="data row14 col0" >1%</td>
#       <td id="T_9e817_row14_col1" class="data row14 col1" >3%</td>
#       <td id="T_9e817_row14_col2" class="data row14 col2" >2%</td>
#       <td id="T_9e817_row14_col3" class="data row14 col3" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_9e817_level0_row15" class="row_heading level0 row15" >Other, please specify</th>
#       <td id="T_9e817_row15_col0" class="data row15 col0" >1%</td>
#       <td id="T_9e817_row15_col1" class="data row15 col1" >2%</td>
#       <td id="T_9e817_row15_col2" class="data row15 col2" >2%</td>
#       <td id="T_9e817_row15_col3" class="data row15 col3" >1%</td>
#     </tr>
#   </tbody>
# </table>
#  BPC2 You indicated that you do not consume information on how to vote, why is that?
# BPC2: all NA values
# Issue with BPC2
#
#
#  BPC3 If you wanted to know more about how elections are run in the United States, where would you be most likely to look for that information? You may select up to 3 choices. \\ National television
# <style type="text/css">
# </style>
# <table id="T_53dfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53dfd_level0_col0" class="col_heading level0 col0" >PID: Dem (no lean)</th>
#       <th id="T_53dfd_level0_col1" class="col_heading level0 col1" >PID: Ind (no lean)</th>
#       <th id="T_53dfd_level0_col2" class="col_heading level0 col2" >PID: Rep (no lean)</th>
#       <th id="T_53dfd_level0_col3" class="col_heading level0 col3" >overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53dfd_level0_row0" class="row_heading level0 row0" >Search through Google or other search engines</th>
#       <td id="T_53dfd_row0_col0" class="data row0 col0" >49%</td>
#       <td id="T_53dfd_row0_col1" class="data row0 col1" >50%</td>
#       <td id="T_53dfd_row0_col2" class="data row0 col2" >46%</td>
#       <td id="T_53dfd_row0_col3" class="data row0 col3" >48%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row1" class="row_heading level0 row1" >Your state election office</th>
#       <td id="T_53dfd_row1_col0" class="data row1 col0" >38%</td>
#       <td id="T_53dfd_row1_col1" class="data row1 col1" >37%</td>
#       <td id="T_53dfd_row1_col2" class="data row1 col2" >39%</td>
#       <td id="T_53dfd_row1_col3" class="data row1 col3" >38%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row2" class="row_heading level0 row2" >Your local election office</th>
#       <td id="T_53dfd_row2_col0" class="data row2 col0" >34%</td>
#       <td id="T_53dfd_row2_col1" class="data row2 col1" >36%</td>
#       <td id="T_53dfd_row2_col2" class="data row2 col2" >38%</td>
#       <td id="T_53dfd_row2_col3" class="data row2 col3" >36%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row3" class="row_heading level0 row3" >Friends and family</th>
#       <td id="T_53dfd_row3_col0" class="data row3 col0" >17%</td>
#       <td id="T_53dfd_row3_col1" class="data row3 col1" >17%</td>
#       <td id="T_53dfd_row3_col2" class="data row3 col2" >19%</td>
#       <td id="T_53dfd_row3_col3" class="data row3 col3" >18%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row4" class="row_heading level0 row4" >National television</th>
#       <td id="T_53dfd_row4_col0" class="data row4 col0" >22%</td>
#       <td id="T_53dfd_row4_col1" class="data row4 col1" >13%</td>
#       <td id="T_53dfd_row4_col2" class="data row4 col2" >15%</td>
#       <td id="T_53dfd_row4_col3" class="data row4 col3" >17%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row5" class="row_heading level0 row5" >Local or regional television</th>
#       <td id="T_53dfd_row5_col0" class="data row5 col0" >16%</td>
#       <td id="T_53dfd_row5_col1" class="data row5 col1" >12%</td>
#       <td id="T_53dfd_row5_col2" class="data row5 col2" >13%</td>
#       <td id="T_53dfd_row5_col3" class="data row5 col3" >14%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row6" class="row_heading level0 row6" >Social media such as Facebook, Twitter, or Instagram</th>
#       <td id="T_53dfd_row6_col0" class="data row6 col0" >17%</td>
#       <td id="T_53dfd_row6_col1" class="data row6 col1" >10%</td>
#       <td id="T_53dfd_row6_col2" class="data row6 col2" >11%</td>
#       <td id="T_53dfd_row6_col3" class="data row6 col3" >13%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row7" class="row_heading level0 row7" >Television news website</th>
#       <td id="T_53dfd_row7_col0" class="data row7 col0" >15%</td>
#       <td id="T_53dfd_row7_col1" class="data row7 col1" >9%</td>
#       <td id="T_53dfd_row7_col2" class="data row7 col2" >12%</td>
#       <td id="T_53dfd_row7_col3" class="data row7 col3" >12%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row8" class="row_heading level0 row8" >Print publications news websites</th>
#       <td id="T_53dfd_row8_col0" class="data row8 col0" >12%</td>
#       <td id="T_53dfd_row8_col1" class="data row8 col1" >10%</td>
#       <td id="T_53dfd_row8_col2" class="data row8 col2" >10%</td>
#       <td id="T_53dfd_row8_col3" class="data row8 col3" >11%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row9" class="row_heading level0 row9" >Print publications, such as newspapers or magazines</th>
#       <td id="T_53dfd_row9_col0" class="data row9 col0" >10%</td>
#       <td id="T_53dfd_row9_col1" class="data row9 col1" >9%</td>
#       <td id="T_53dfd_row9_col2" class="data row9 col2" >10%</td>
#       <td id="T_53dfd_row9_col3" class="data row9 col3" >10%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row10" class="row_heading level0 row10" >Blogs or online forums</th>
#       <td id="T_53dfd_row10_col0" class="data row10 col0" >7%</td>
#       <td id="T_53dfd_row10_col1" class="data row10 col1" >6%</td>
#       <td id="T_53dfd_row10_col2" class="data row10 col2" >6%</td>
#       <td id="T_53dfd_row10_col3" class="data row10 col3" >6%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row11" class="row_heading level0 row11" >Radio</th>
#       <td id="T_53dfd_row11_col0" class="data row11 col0" >5%</td>
#       <td id="T_53dfd_row11_col1" class="data row11 col1" >5%</td>
#       <td id="T_53dfd_row11_col2" class="data row11 col2" >5%</td>
#       <td id="T_53dfd_row11_col3" class="data row11 col3" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row12" class="row_heading level0 row12" >Podcasts</th>
#       <td id="T_53dfd_row12_col0" class="data row12 col0" >6%</td>
#       <td id="T_53dfd_row12_col1" class="data row12 col1" >5%</td>
#       <td id="T_53dfd_row12_col2" class="data row12 col2" >5%</td>
#       <td id="T_53dfd_row12_col3" class="data row12 col3" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row13" class="row_heading level0 row13" >I am not interested in learning about how elections are run in the United States</th>
#       <td id="T_53dfd_row13_col0" class="data row13 col0" >2%</td>
#       <td id="T_53dfd_row13_col1" class="data row13 col1" >5%</td>
#       <td id="T_53dfd_row13_col2" class="data row13 col2" >3%</td>
#       <td id="T_53dfd_row13_col3" class="data row13 col3" >3%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row14" class="row_heading level0 row14" >Don't know/ no opinion</th>
#       <td id="T_53dfd_row14_col0" class="data row14 col0" >2%</td>
#       <td id="T_53dfd_row14_col1" class="data row14 col1" >3%</td>
#       <td id="T_53dfd_row14_col2" class="data row14 col2" >3%</td>
#       <td id="T_53dfd_row14_col3" class="data row14 col3" >3%</td>
#     </tr>
#     <tr>
#       <th id="T_53dfd_level0_row15" class="row_heading level0 row15" >Other, please specify</th>
#       <td id="T_53dfd_row15_col0" class="data row15 col0" >1%</td>
#       <td id="T_53dfd_row15_col1" class="data row15 col1" >2%</td>
#       <td id="T_53dfd_row15_col2" class="data row15 col2" >1%</td>
#       <td id="T_53dfd_row15_col3" class="data row15 col3" >1%</td>
#     </tr>
#   </tbody>
# </table>
#  BPC4 You indicated that you are not interested in learning about how elections are run in the United States , why is that?
# BPC4: all NA values
# Issue with BPC4
